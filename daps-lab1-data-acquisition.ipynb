# %% [markdown]
# # Task 1: Small case scenario of dataset analysis

# %% [markdown]
# ## 1.1 - Create a dataset (The Tate Collection)
# As a first example, we will create our own small dataset. In particular, the dataset will consist of 10 artists which are present in the Tate Collection along with the corresponding year of birth, year of death, biological gender and number of artworks.
#
# |          Name         | Gender |   Year_Birth  |   Year_Death  | N_works |
# |-----------------------|--------|---------------|---------------|---------|
# |     Beuys, Joseph     |  Male  |      1921	 |      1986     |   588   |
# |    Constable, John    |  Male  |      1776	 |      1837	 |   249   |
# |   Daniell, William    |  Male  |      1769	 |      1837	 |   612   |
# |   Forbes, Elizabeth   | Female |      1859	 |      1912	 |   120   |
# |     Flaxman, John     |  Male  |      1755	 |      1826	 |   287   |
# |    Phillips, Thomas   |  Male  |      1770	 |      1845	 |   274   |
# | Paolozzi, Sir Eduardo |  Male  |      1924	 |      2005	 |   385   |
# |     Schendel, Mira    | Female |      1919	 |      1988	 |    3    |
# |    Turner, William    |  Male  |      1775	 |      1851	 |  1861   |
# |      Warhol, Andy     |  Male  |      1928	 |      1987	 |   272   |

# %% [markdown]
# **_[TO DO]_**: Let's create a DataFrame named **TateDataset** with the information showed in the above table.
#
# **Note:** You can create arrays for each column and then build the DataFrame.
# Remember to import the required libraries!

# %%
# @title Imports
import numpy as np
import pandas as pd

# %%
### TODO
dataseries_set = {'Name':pd.Series(['Beuys, Joseph','Constable, John','Daniell, William','Forbes, Elizabeth',
                              'Flaxman, John','Phillips, Thomas','Paolozzi, Sir Eduardo','Schendel, Mira',
                               'Turner, William','Warhol, Andy']),
            'Gender':pd.Series(['Male','Male','Male','Female','Male','Male','Female','Male','Male']),
            'Year_Birth':pd.Series([1921,1776,1769,1859,1755,1770,1924,1919,1775,1928]),
            'Year_Death':pd.Series([1986,1837,1837,1912,1826,1845,2005,1988,1851,1987]),
            'N_works':pd.Series([588,249,612,120,287,274,385,3,1861,272])}
            
tate_dataset = pd.DataFrame(dataseries_set)
print(tate_dataset)
# Out:
#                     Name  Gender  Year_Birth  Year_Death  N_works
# 0          Beuys, Joseph    Male        1921        1986      588
# 1        Constable, John    Male        1776        1837      249
# 2       Daniell, William    Male        1769        1837      612
# 3      Forbes, Elizabeth  Female        1859        1912      120
# 4          Flaxman, John    Male        1755        1826      287
# 5       Phillips, Thomas    Male        1770        1845      274
# 6  Paolozzi, Sir Eduardo  Female        1924        2005      385
# 7         Schendel, Mira    Male        1919        1988        3
# 8        Turner, William    Male        1775        1851     1861
# 9           Warhol, Andy     NaN        1928        1987      272

# %% [markdown]
# ## 1.2 - Data Acquisition (local file)
#
# Data acquisition is a process of loading and reading data from various sources. We will learn how to export and read data from a local file in different format using  **Pandas** package.
#
# A file format is a standardised way in which information is encoded to be stored in a file. Some examples of file formats are: CSV, XLSX, and PKL.
#
# Let's practice with some examples.
#
# ### .CSV - Comma Separated Values
#
# CSV is one of the most popular spreadsheet file format. In this kind of file, data is stored in cells. Each cell is organized in rows and columns. A column in the spreadsheet file can have different types.
#
# Let us look at how to create a CSV file. We can export a DataFrame with the Pandas function `to_csv()`. The file will be saved in the same location of this notebook unless specified otherwise. We can name the file **TateData.csv**.
#
# **Note:** Once you have run the following cell, check the output file .

# %%
tate_dataset.to_csv('tate_dataset.csv', index=False, header=True)

# %% [markdown]
# To pull in the csv file, we will use the Pandas function `read_csv()`. We will import the previous file in a new DataFrame.
#
# **Note:**  Depending on where you save your notebooks, you may need to modify the location below.

# %%
tate_1 = pd.read_csv('tate_dataset.csv')
tate_1
# Out:
#                     Name  Gender  Year_Birth  Year_Death  N_works
# 0          Beuys, Joseph    Male        1921        1986      588
# 1        Constable, John    Male        1776        1837      249
# 2       Daniell, William    Male        1769        1837      612
# 3      Forbes, Elizabeth  Female        1859        1912      120
# 4          Flaxman, John    Male        1755        1826      287
# 5       Phillips, Thomas    Male        1770        1845      274
# 6  Paolozzi, Sir Eduardo  Female        1924        2005      385
# 7         Schendel, Mira    Male        1919        1988        3
# 8        Turner, William    Male        1775        1851     1861
# 9           Warhol, Andy     NaN        1928        1987      272

# %% [markdown]
# When we create the .CSV file, the only parameter we have used is **index**.
#
# **[TO DO]** What happens if we set the *index* parameter to True? And if you set also the parameter **header** to False?
# Try by yourself.

# %%
### TODO

# %% [markdown]
# Delete the csv file now that we are done using it.

# %% [markdown]
# ### pickle — Python object serialization
#
# This data format is Python-specific. This has the advantage that there are no restrictions imposed by external standards; however it means that non-Python programs may not be able to reconstruct pickled Python objects.

# %%
import pickle

tate_dataset.to_pickle('tate_dataset.pkl')

# %%
tate_2 = pd.read_pickle('tate_dataset.pkl')
tate_2
# Out:
#                     Name  Gender  Year_Birth  Year_Death  N_works
# 0          Beuys, Joseph    Male        1921        1986      588
# 1        Constable, John    Male        1776        1837      249
# 2       Daniell, William    Male        1769        1837      612
# 3      Forbes, Elizabeth  Female        1859        1912      120
# 4          Flaxman, John    Male        1755        1826      287
# 5       Phillips, Thomas    Male        1770        1845      274
# 6  Paolozzi, Sir Eduardo  Female        1924        2005      385
# 7         Schendel, Mira    Male        1919        1988        3
# 8        Turner, William    Male        1775        1851     1861
# 9           Warhol, Andy     NaN        1928        1987      272

# %% [markdown]
# ## 1.3 - Look at the data
#
# Now we will simply have a look at the data and make sure it is clean.
#
# ### Data type
# Let's check the data type of the imported variables and the original DataFrame.

# %%
# Check data type of the columns for Tate_1
tate_1.dtypes
# Out:
# Name          object
# Gender        object
# Year_Birth     int64
# Year_Death     int64
# N_works        int64
# dtype: object

# %%
# Check data type of the columns for TateDataset
tate_dataset.dtypes
# Out:
# Name          object
# Gender        object
# Year_Birth     int64
# Year_Death     int64
# N_works        int64
# dtype: object

# %% [markdown]
# We can also display the values of a single column and check their data type as follow:

# %%
tate_dataset['Gender']
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3    Female
# 4      Male
# 5      Male
# 6    Female
# 7      Male
# 8      Male
# 9       NaN
# Name: Gender, dtype: object

# %% [markdown]
# # Task 2: Application Programming Interfaces (APIs)

# %% [markdown]
# ## 2.1 - Downloading climate data from the Internet
#
# We will now explore real world data, namely a dataset of climate information of 5 cities in Denmark between 1980-2018. The original raw-data was originally obtained from [National Climatic Data Center (NCDC)](https://www7.ncdc.noaa.gov/CDO/cdoselect.cmd).
#
# In particular, the selected cities in Denmark are:
# - Aalborg,
# - Aarhus,
# - Esbjerg,
# - Odense.
# - Roskilde
#
# In the following, we will download the dataset using an API instead of loading a local source file.
#
# ### What is an API?
# Application Programming Interface (API) is a communication protocol between the user and the server (i.e., web server) that enables transmittion of data. The user making a request to an API server can download the desidered resources.
#
# ### How to make a request in python?
# There are many different way to request data.
# In the following, we will use the package **urllib** that collects several modules for working with URLs.
#
# In particular, [urlib.request](https://docs.python.org/3/library/urllib.request.html#module-urllib.request) is a module for opening and reading URLs.

# %% [markdown]
# ### - Download climate data
#
#
# The following functions allow to download and store the dataset in a specific folder.
#
# How to use:
#
# - Set the source (i.e., URL) of the desidered dataset in `data_url`.
# - Set the `data_dir` variable with the local directory where to store the data.
# - Call `download_and_extract()` to download the dataset if it is not already located in the given data_dir.
# - Load the data in the interactive Python notebook so ic can be used in your scripts (you can use `load_original_data()`).

# %%
#@title Functions to download data 
########################################################################
#
# This file is a partially modified version of one of the TensorFlow Tutorials available at:
#
# https://github.com/Hvass-Labs/TensorFlow-Tutorials
#
# Published under the MIT License. See the file LICENSE for details.
#
# Copyright 2018 by Magnus Erik Hvass Pedersen
#
########################################################################

import sys
import os
import urllib.request
import tarfile
import zipfile



def _print_download_progress(count, block_size, total_size):
    """
    Function used for printing the download progress.
    Used as a call-back function in maybe_download_and_extract().
    """

    # Percentage completion.
    pct_complete = float(count * block_size) / total_size

    # Limit it because rounding errors may cause it to exceed 100%.
    pct_complete = min(1.0, pct_complete)

    # Status-message. Note the \r which means the line should overwrite itself.
    msg = "\r- Download progress: {0:.1%}".format(pct_complete)

    # Print it.
    sys.stdout.write(msg)
    sys.stdout.flush()


def download(base_url, filename, download_dir):
    """
    Download the given file if it does not already exist in the download_dir.
    :param base_url: The internet URL without the filename.
    :param filename: The filename that will be added to the base_url.
    :param download_dir: Local directory for storing the file.
    """

    # Path for local file.
    save_path = os.path.join(download_dir, filename)

    # Check if the file already exists, otherwise we need to download it now.
    if not os.path.exists(save_path):
        # Check if the download directory exists, otherwise create it.
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)

        print("Downloading", filename, "...")

        # Download the file from the internet.
        url = base_url + filename
        file_path, _ = urllib.request.urlretrieve(url=url,
                                                  filename=save_path,
                                                  reporthook=_print_download_progress)

        print(" Done!")


def download_and_extract(url, download_dir):
    """
    Download and extract the data if it doesn't already exist.
    Assumes the url is a tar-ball file.
    :param url:
        Internet URL for the tar-file to download.
    :param download_dir:
        Directory where the downloaded file is saved.
    """

    # Filename for saving the file downloaded from the internet.
    # Use the filename from the URL and add it to the download_dir.
    filename = url.split('/')[-1]
    file_path = os.path.join(download_dir, filename)

    # Check if the file already exists.
    # If it exists then we assume it has also been extracted,
    # otherwise we need to download and extract it now.
    if not os.path.exists(file_path):
        # Check if the download directory exists, otherwise create it.
        if not os.path.exists(download_dir):
            os.makedirs(download_dir)

        # Download the file from the internet.
        file_path, _ = urllib.request.urlretrieve(url=url,
                                                  filename=file_path,
                                                  reporthook=_print_download_progress)

        print()
        print("Download finished. Extracting files.")

        if file_path.endswith(".zip"):
            # Unpack the zip-file.
            zipfile.ZipFile(file=file_path, mode="r").extractall(download_dir)
        elif file_path.endswith((".tar.gz", ".tgz")):
            # Unpack the tar-ball.
            tarfile.open(name=file_path, mode="r:gz").extractall(download_dir)

        print("Done.")
    else:
        print("Data has apparently already been downloaded and unpacked.")

# %% [markdown]
# First, we define where we want to download the dataset (you are free to choose another directory) and the URL of the dataset to be downloaded.

# %%
# Location of the dataset on the internet.
data_url = "https://github.com/Hvass-Labs/weather-denmark/raw/master/weather-denmark.tar.gz"

# Local directory where you want to download and save the dataset.
data_dir = "weather-data/"

# %% [markdown]
# Now, we can download the dataset into the chosen local directory

# %%
download_and_extract(url=data_url, download_dir=data_dir)
# Out:
# - Download progress: 100.0%
# Download finished. Extracting files.
# Done.

# %% [markdown]
# **[TO DO]:** Check the local folder? In which format the dataset has been downloaded?
#
# **[TO DO]:** Select a format and load the dataset .

# %%
### TODO
# csv,plk,tar.gz

# %%
### TODO
dataset = pd.read_csv('C:/Users/s2689/github-starter-course/1-data-acquisition-FelixLi15/weather_data/weather-denmark.csv')

# %% [markdown]
# **More advanced solution for loading dataset**:
#
# In this case, the dataset was downloaded in two different formats.
# We can define the path where the files have been stored as follows:
# - **path_original_data_pickle( )** is the location of the original data in pickle format
# - **path_original_data_csv( )** is the location the original data in .csv

# %%
def path_original_data_pickle(data_dir):
    return os.path.join(data_dir, "weather-denmark.pkl")

def path_original_data_csv(data_dir):
    return os.path.join(data_dir, "weather-denmark.csv")

# %% [markdown]
# Now we can load the data in pickle format through the following function:

# %%
def load_original_data(data_dir):
    return pd.read_pickle(path_original_data_pickle(data_dir))

# %%
data_dir = 'C:/Users/s2689/github-starter-course/1-data-acquisition-FelixLi15/weather_data/'
df = load_original_data(data_dir)
df
# Out:
#                               Temp  Pressure  WindSpeed  WindDir
# City     DateTime
# Aalborg  1980-03-01 00:00:00   5.0    1008.1       11.3    290.0
#          1980-03-01 00:20:00   4.0       NaN        9.2    270.0
#          1980-03-01 00:50:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:20:00   4.0       NaN        9.2    280.0
#          1980-03-01 01:50:00   4.0       NaN        8.7    270.0
# ...                            ...       ...        ...      ...
# Roskilde 2018-03-01 22:20:00  -5.0       NaN        5.1     70.0
#          2018-03-01 22:50:00  -5.0       NaN        4.1     70.0
#          2018-03-01 23:00:00  -5.3    1018.6        4.1     60.0
#          2018-03-01 23:20:00  -5.0       NaN        3.6     60.0
#          2018-03-01 23:50:00  -5.0       NaN        3.6     60.0
#
# [2918150 rows x 4 columns]

# %% [markdown]
# ### - Undestanding the data
#
# **_[TO DO]_**: Have a quick overview of the downloaded dataset.
# In particular, focus on:
#
# - Understanding the variables contained in the dataframe
# - Check the DateTime for 2 cities

# %%
### TODO

# %% [markdown]
# ## 2.2 - Interacting with a server to query a subset of some data bank
#
# We will now learn how to query a data bank to retrieve only the relevant proportion data for a task. We will be using the World Bank Data API to access World's renewable energy consumtpion data.

# %% [markdown]
# You first need to install the World Bank API. In a terminal, run the following command:
#
# ``>> pip install wbdata``

# %%
# %pip install wbdata
# Out:
# Collecting wbdataNote: you may need to restart the kernel to use updated packages.
#
#   Using cached wbdata-0.3.0-py3-none-any.whl (14 kB)
# Collecting appdirs<2.0,>=1.4
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting requests>=2.0
#   Using cached requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting tabulate>=0.8.5
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: decorator>=4.0 in d:\anaconda\envs\daps\lib\site-packages (from wbdata) (5.1.1)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      ------------------------------------ 140.4/140.4 kB 333.7 kB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      -------------------------------------- 61.5/61.5 kB 657.7 kB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\daps\lib\site-packages (from requests>=2.0->wbdata) (2022.9.24)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Installing collected packages: appdirs, urllib3, tabulate, idna, charset-normalizer, requests, wbdata
# Successfully installed appdirs-1.4.4 charset-normalizer-2.1.1 idna-3.4 requests-2.28.1 tabulate-0.9.0 urllib3-1.26.12 wbdata-0.3.0

# %%
#@title Imports
import wbdata as wb
import datetime

# %% [markdown]
# ### - Query the World Bank
#
# * **_[TO DO]_**: Use the wbdata to retrieve renewable energy consumption data of all countries in 2015.
#
# Hint: [wbdata documentation](https://wbdata.readthedocs.io/en/stable/)

# %%
### TODO
data_date=datetime.datetime(2015,1,1),datetime.datetime(2015,12,31)
wb.get_source()
wb.get_indicator(source=35)
wb.get_data('2.1_SHARE.TOTAL.RE.IN.TFEC',country='all',data_date=data_date)
# Out:
# [{'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BES', 'value': 'BES Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.96987679690112,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'NRU', 'value': 'Nauru'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.0762903659245616,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'NIU', 'value': 'Niue'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 22.3681265799767,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'WLF', 'value': 'Wallis and Futuna'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CCA', 'value': 'Caucasian and Central Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GCA', 'value': 'Caucasus and Central Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GEJ', 'value': 'Eastern Asia (including Japan)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GEA', 'value': 'Eastern Asia (not including Japan)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GEE', 'value': 'Eastern Europe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GEU', 'value': 'Europe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'HIC', 'value': 'High income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'NOC', 'value': 'High income: nonOECD'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'OEC', 'value': 'High income: OECD'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GLC', 'value': 'Latin America and Caribbean'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LMY', 'value': 'Low & middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LIC', 'value': 'Low income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LMC', 'value': 'Lower middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MIC', 'value': 'Middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GNA', 'value': 'Northern America'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LNX', 'value': 'Not classified'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'NAR', 'value': 'Nothern America'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GCN', 'value': 'Oceania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GOC',
#    'value': 'Oceania (not including Australia and New Zealand)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GSE', 'value': 'South Eastern Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GSA', 'value': 'Southern Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GSS', 'value': 'Sub-Saharan Africa'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'UMC', 'value': 'Upper middle income'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GWA', 'value': 'Western Asia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GWL', 'value': 'World'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'AFG', 'value': 'Afghanistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 18.4234771693218,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ALB', 'value': 'Albania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 38.6152104692153,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'DZA', 'value': 'Algeria'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.0589586840918149,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ASM', 'value': 'American Samoa'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.885478201974834,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'AND', 'value': 'Andorra'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 19.7478086257358,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'AGO', 'value': 'Angola'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 49.5682103295777,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'AIA', 'value': 'Anguilla'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.11285043395223,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ATG', 'value': 'Antigua and Barbuda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ARG', 'value': 'Argentina'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 10.040077613914,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ARM', 'value': 'Armenia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 15.7920038357833,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ABW', 'value': 'Aruba'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6.72674756598399,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'AUS', 'value': 'Australia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9.18050295980786,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'AUT', 'value': 'Austria'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 34.3949917477854,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'AZE', 'value': 'Azerbaijan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.31075768577815,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BHS', 'value': 'Bahamas, The'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.21051288380392,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BHR', 'value': 'Bahrain'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BGD', 'value': 'Bangladesh'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 34.7470690115416,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BRB', 'value': 'Barbados'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.78635820637435,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BLR', 'value': 'Belarus'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6.7708695317313,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BEL', 'value': 'Belgium'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9.20164053078148,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BLZ', 'value': 'Belize'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 35.0236296024311,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BEN', 'value': 'Benin'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 50.8626179373594,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BMU', 'value': 'Bermuda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.3595880074697,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BTN', 'value': 'Bhutan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 86.9045483179462,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BOL', 'value': 'Bolivia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 17.5381818257023,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BIH', 'value': 'Bosnia and Herzegovina'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 40.7500602307998,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BWA', 'value': 'Botswana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 28.8798269935477,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BRA', 'value': 'Brazil'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 43.7903891971588,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'VGB', 'value': 'British Virgin Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.22913566907501,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BRN', 'value': 'Brunei Darussalam'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.0149350358914578,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BGR', 'value': 'Bulgaria'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 17.6500779274042,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BFA', 'value': 'Burkina Faso'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 74.1671878585048,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'BDI', 'value': 'Burundi'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 95.6789242535879,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KHM', 'value': 'Cambodia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 64.9237759106607,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CMR', 'value': 'Cameroon'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 76.5384004118885,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CAN', 'value': 'Canada'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 22.0253592107108,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CPV', 'value': 'Cape Verde'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 26.5797158996811,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CYM', 'value': 'Cayman Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CAF', 'value': 'Central African Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 76.5670200103872,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TCD', 'value': 'Chad'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 89.357395570733,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CHI', 'value': 'Channel Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CHL', 'value': 'Chile'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 24.8825542739544,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CHN', 'value': 'China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 12.4133525698911,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'COL', 'value': 'Colombia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 23.5647575160943,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'COM', 'value': 'Comoros'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 45.3330523920407,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'COD', 'value': 'Congo, Dem. Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 95.8176997146271,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'COG', 'value': 'Congo, Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 62.4021190190415,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'COK', 'value': 'Cook Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CRI', 'value': 'Costa Rica'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 38.7334138821774,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CIV', 'value': "Cote d'Ivoire"},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 64.5280256540323,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'HRV', 'value': 'Croatia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 33.1274666358571,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CUB', 'value': 'Cuba'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 19.2813206353885,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CUW', 'value': 'Curacao'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.347766267819474,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CYP', 'value': 'Cyprus'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9.9420660163921,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CZE', 'value': 'Czech Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 14.8285619496241,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'DNK', 'value': 'Denmark'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 33.1702771730605,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'DJI', 'value': 'Djibouti'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 15.3805952215024,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'DMA', 'value': 'Dominica'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7.82979664019173,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'DOM', 'value': 'Dominican Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 16.480109206897,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ECU', 'value': 'Ecuador'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13.8166859421647,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'EGY', 'value': 'Egypt, Arab Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5.70937726460422,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SLV', 'value': 'El Salvador'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 24.400769994085,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GNQ', 'value': 'Equatorial Guinea'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7.82279977697172,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ERI', 'value': 'Eritrea'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 79.767472303226,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'EST', 'value': 'Estonia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 27.4768334658828,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ETH', 'value': 'Ethiopia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 92.163461141348,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'FRO', 'value': 'Faeroe Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7.51358049162428,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'FLK', 'value': 'Falkland Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3.88882791631324,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'FJI', 'value': 'Fiji'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 31.2639470878642,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'FIN', 'value': 'Finland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 43.2352625898503,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'FRA', 'value': 'France'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13.4992623166677,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GUF', 'value': 'French Guyana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 32.4383639829181,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'PYF', 'value': 'French Polynesia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9.82915476747146,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GAB', 'value': 'Gabon'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 82.0078436860573,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GMB', 'value': 'Gambia, The'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 51.5088624939659,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GEO', 'value': 'Georgia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 28.662538805976,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'DEU', 'value': 'Germany'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 14.2062526977772,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GHA', 'value': 'Ghana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 41.4127943140724,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GIB', 'value': 'Gibraltar'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GRC', 'value': 'Greece'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 17.170047546133,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GRL', 'value': 'Greenland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 15.5338165059432,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GRD', 'value': 'Grenada'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 10.9195721498431,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GLP', 'value': 'Guadeloupe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4.68285519771806,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GUM', 'value': 'Guam'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GTM', 'value': 'Guatemala'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 63.6509917919234,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GIN', 'value': 'Guinea'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 76.2683913195384,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GNB', 'value': 'Guinea-Bissau'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 86.8517939369185,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GUY', 'value': 'Guyana'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 25.2587277167556,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'HTI', 'value': 'Haiti'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 76.0722132337506,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'HND', 'value': 'Honduras'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 51.5374135797421,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'HKG', 'value': 'Hong Kong SAR, China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.852783452322141,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'HUN', 'value': 'Hungary'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 15.559362050795,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ISL', 'value': 'Iceland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 77.029689205553,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'IND', 'value': 'India'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 36.0212225652817,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'IDN', 'value': 'Indonesia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 36.8793481032359,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'IRN', 'value': 'Iran, Islamic Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.913005056748309,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'IRQ', 'value': 'Iraq'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.798830768676665,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'IRL', 'value': 'Ireland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9.08139901337063,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'IMN', 'value': 'Isle of Man'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4.2075897300392,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ISR', 'value': 'Israel'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3.70776691254672,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ITA', 'value': 'Italy'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 16.5168505774397,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'JAM', 'value': 'Jamaica'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 16.7719074601531,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'JPN', 'value': 'Japan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 6.29735708059289,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'JOR', 'value': 'Jordan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3.22917004202291,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KAZ', 'value': 'Kazakhstan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.55844291225827,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KEN', 'value': 'Kenya'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 72.662752510447,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KIR', 'value': 'Kiribati'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4.25399869303377,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'PRK', 'value': 'Korea, Dem. Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 23.1232614917341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KOR', 'value': 'Korea, Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.70770280422964,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'XKX', 'value': 'Kosovo'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 20.4509089678075,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KWT', 'value': 'Kuwait'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KGZ', 'value': 'Kyrgyz Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 23.3068222046976,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LAO', 'value': 'Lao PDR'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 59.3158607506634,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LVA', 'value': 'Latvia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 38.0980171666829,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LBN', 'value': 'Lebanon'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3.64671967049883,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LSO', 'value': 'Lesotho'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 52.139206087139,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LBR', 'value': 'Liberia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 83.84704333625,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LBY', 'value': 'Libya'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.96655445725932,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LIE', 'value': 'Liechtenstein'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 63.1344414422166,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LTU', 'value': 'Lithuania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 28.9611792543763,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LUX', 'value': 'Luxembourg'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9.03131366096732,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MAC', 'value': 'Macao SAR, China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 7.0513630489631,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MKD', 'value': 'Macedonia, FYR'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 24.2181297260889,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MDG', 'value': 'Madagascar'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 70.1744159107341,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MWI', 'value': 'Malawi'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 83.649433704296,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MYS', 'value': 'Malaysia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5.19444258901529,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MDV', 'value': 'Maldives'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.00959469325713,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MLI', 'value': 'Mali'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 61.5269847175779,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MLT', 'value': 'Malta'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5.35500474641897,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MHL', 'value': 'Marshall Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 11.1644846525257,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MTQ', 'value': 'Martinique'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.44816688846927,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MRT', 'value': 'Mauritania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 32.1595724693392,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MUS', 'value': 'Mauritius'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 11.5373619624728,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MYT', 'value': 'Mayotte'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 10.2435998757398,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MEX', 'value': 'Mexico'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 9.2152134550018,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'FSM', 'value': 'Micronesia, Fed. Sts.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.19623786232284,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MDA', 'value': 'Moldova'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 14.2736887091697,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MCO', 'value': 'Monaco'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MNG', 'value': 'Mongolia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3.42973728977845,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MNE', 'value': 'Montenegro'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 43.004060548998,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MSR', 'value': 'Montserrat'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MAR', 'value': 'Morocco'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 11.3174596346938,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MOZ', 'value': 'Mozambique'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 86.4005089176123,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MMR', 'value': 'Myanmar'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 61.5278116473242,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'NAM', 'value': 'Namibia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 26.4684298435307,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'NPL', 'value': 'Nepal'},
#   'countryiso3code': '',
# ...
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 34.3248944081542,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SMR', 'value': 'San Marino'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'STP', 'value': 'Sao Tome and Principe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 41.0559989770475,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SAU', 'value': 'Saudi Arabia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.00597654216323794,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SEN', 'value': 'Senegal'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 42.7117516284132,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SRB', 'value': 'Serbia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 21.1738852789742,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SYC', 'value': 'Seychelles'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.35293554797754,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SLE', 'value': 'Sierra Leone'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 77.660558628128,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SGP', 'value': 'Singapore'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.70863529719762,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SXM', 'value': 'Sint Maarten (Dutch part)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.0463340318516937,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SVK', 'value': 'Slovak Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13.4091682209694,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SVN', 'value': 'Slovenia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 20.8773961432658,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SLB', 'value': 'Solomon Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 63.3074463971862,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SOM', 'value': 'Somalia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 94.2859666089416,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ZAF', 'value': 'South Africa'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 17.1501412476598,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SSD', 'value': 'South Sudan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 39.0743843216671,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ESP', 'value': 'Spain'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 16.254097737239,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LKA', 'value': 'Sri Lanka'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 52.8758920368984,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SHN', 'value': 'St. Helena'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 12.5975170464467,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'KNA', 'value': 'St. Kitts and Nevis'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.64219119447618,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'LCA', 'value': 'St. Lucia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.13262353619368,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'MAF', 'value': 'St. Martin (French part)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'VCT', 'value': 'St. Vincent and the Grenadines'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 5.80743339677968,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SDN', 'value': 'Sudan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 61.5967474758976,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SUR', 'value': 'Suriname'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 24.9131103610308,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SWZ', 'value': 'Swaziland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 66.1046592063012,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SWE', 'value': 'Sweden'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 53.2477697984376,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'CHE', 'value': 'Switzerland'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 25.2919836825127,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'SYR', 'value': 'Syrian Arab Republic'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.52115517170161,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TWN', 'value': 'Taiwan, China'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.11532023769111,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TJK', 'value': 'Tajikistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 44.6592039196129,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TZA', 'value': 'Tanzania'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 85.7130419384343,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'THA', 'value': 'Thailand'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 22.8630701280756,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TLS', 'value': 'Timor-Leste'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 18.2236892844473,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TGO', 'value': 'Togo'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 71.2646671412409,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TON', 'value': 'Tonga'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 1.87975158224647,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TTO', 'value': 'Trinidad and Tobago'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.284205763881456,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TUN', 'value': 'Tunisia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 12.5623503533853,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TUR', 'value': 'Turkey'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 13.3742300375217,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TKM', 'value': 'Turkmenistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.0408878864181804,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TCA', 'value': 'Turks and Caicos Islands'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.572166001038355,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'TUV', 'value': 'Tuvalu'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'UGA', 'value': 'Uganda'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 89.0579489792097,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'UKR', 'value': 'Ukraine'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 4.14431803937237,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ARE', 'value': 'United Arab Emirates'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 0.137108046073838,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'GBR', 'value': 'United Kingdom'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 8.71168557437913,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'USA', 'value': 'United States'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 8.71693586705814,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'URY', 'value': 'Uruguay'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 58.0220411778528,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'UZB', 'value': 'Uzbekistan'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.97017869966095,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'VUT', 'value': 'Vanuatu'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 36.111064596662,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'VEN', 'value': 'Venezuela, RB'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 12.8415785518796,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'VNM', 'value': 'Vietnam'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 34.9985698382085,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'VIR', 'value': 'Virgin Islands (U.S.)'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 3.87752521400119,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'PSE', 'value': 'West Bank and Gaza'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 10.4727149640955,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ESH', 'value': 'Western Sahara'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'YEM', 'value': 'Yemen, Rep.'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 2.27641668698264,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ZMB', 'value': 'Zambia'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 87.9854523585353,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2},
#  {'indicator': {'id': '2.1_SHARE.TOTAL.RE.IN.TFEC',
#    'value': 'Renewable energy share of TFEC (%)'},
#   'country': {'id': 'ZWE', 'value': 'Zimbabwe'},
#   'countryiso3code': '',
#   'date': '2015',
#   'value': 81.797808552401,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 2}]

# %% [markdown]
# ### - Undestanding the data
#
# * **_[TO DO]_**: Display different data points

# %%
### TODO
ds=wb.get_series('2.1_SHARE.TOTAL.RE.IN.TFEC',country='all',data_date=data_date)
df=pd.DataFrame(ds)

# %% [markdown]
# ### - Exporting the data
#
# * **_[TO DO]_**: Save the retrieved renewable energy consumption data of all countries in 2015 in one .xlsx file
# * **_[TO DO]_**: Save the renewable energy consumption data from 2006 to 2016 for each European country in individual .csv files (one per country)

# %%
### TODO
import openpyxl
df.to_excel(excel_writer='renewable energy consumption data.xlsx')

# %%
import numpy as np
import wbdata as wb
import datetime
data_date = datetime.datetime(2006,1,1),datetime.datetime(2016,12,31)
indicators= {'3.1_RE.CONSUMPTION':    'Renewable energy consumption (TJ)'}
countrys=['CHN','USA']
df = wb.get_dataframe(indicators,country=countrys,data_date=data_date)
rows=len(df.index)
country=int(rows/11)
for i in range(country):
    dfCH = df.iloc[11*(i):11*(i+1),:]
    print(dfCH)
# Out:
#               Renewable energy consumption (TJ)
# country date
# China   2016                                NaN
#         2015                          9084482.0
#         2014                          8744472.0
#         2013                          8275653.0
#         2012                          8069989.0
#         2011                          7655961.0
#         2010                          7871450.0
#         2009                          7920214.0
#         2008                          7986006.0
#         2007                          8108961.0
#         2006                          8406294.0
#                     Renewable energy consumption (TJ)
# country       date
# United States 2016                                NaN
#               2015                          5097931.0
#               2014                          5175231.0
#               2013                          5052304.0
#               2012                          4802944.0
#               2011                          4663837.0
#               2010                          4327122.0
#               2009                          4070025.0
#               2008                          3989400.0
#               2007                          3755210.0
#               2006                          3755239.0

# %%
wb.get_country()
# Out:
# id    name
# ----  --------------------------------------------------------------------------------
# ABW   Aruba
# AFE   Africa Eastern and Southern
# AFG   Afghanistan
# AFR   Africa
# AFW   Africa Western and Central
# AGO   Angola
# ALB   Albania
# AND   Andorra
# ARB   Arab World
# ARE   United Arab Emirates
# ARG   Argentina
# ARM   Armenia
# ASM   American Samoa
# ATG   Antigua and Barbuda
# AUS   Australia
# AUT   Austria
# AZE   Azerbaijan
# BDI   Burundi
# BEA   East Asia & Pacific (IBRD-only countries)
# BEC   Europe & Central Asia (IBRD-only countries)
# BEL   Belgium
# BEN   Benin
# BFA   Burkina Faso
# BGD   Bangladesh
# BGR   Bulgaria
# BHI   IBRD countries classified as high income
# BHR   Bahrain
# BHS   Bahamas, The
# BIH   Bosnia and Herzegovina
# BLA   Latin America & the Caribbean (IBRD-only countries)
# BLR   Belarus
# BLZ   Belize
# BMN   Middle East & North Africa (IBRD-only countries)
# BMU   Bermuda
# BOL   Bolivia
# BRA   Brazil
# BRB   Barbados
# BRN   Brunei Darussalam
# BSS   Sub-Saharan Africa (IBRD-only countries)
# BTN   Bhutan
# BWA   Botswana
# CAA   Sub-Saharan Africa (IFC classification)
# CAF   Central African Republic
# CAN   Canada
# CEA   East Asia and the Pacific (IFC classification)
# CEB   Central Europe and the Baltics
# CEU   Europe and Central Asia (IFC classification)
# CHE   Switzerland
# CHI   Channel Islands
# CHL   Chile
# CHN   China
# CIV   Cote d'Ivoire
# CLA   Latin America and the Caribbean (IFC classification)
# CME   Middle East and North Africa (IFC classification)
# CMR   Cameroon
# COD   Congo, Dem. Rep.
# COG   Congo, Rep.
# COL   Colombia
# COM   Comoros
# CPV   Cabo Verde
# CRI   Costa Rica
# CSA   South Asia (IFC classification)
# CSS   Caribbean small states
# CUB   Cuba
# CUW   Curacao
# CYM   Cayman Islands
# CYP   Cyprus
# CZE   Czechia
# DEA   East Asia & Pacific (IDA-eligible countries)
# DEC   Europe & Central Asia (IDA-eligible countries)
# DEU   Germany
# DFS   IDA countries classified as Fragile Situations
# DJI   Djibouti
# DLA   Latin America & the Caribbean (IDA-eligible countries)
# DMA   Dominica
# DMN   Middle East & North Africa (IDA-eligible countries)
# DNF   IDA countries not classified as Fragile Situations
# DNK   Denmark
# DNS   IDA countries in Sub-Saharan Africa not classified as fragile situations
# DOM   Dominican Republic
# DSA   South Asia (IDA-eligible countries)
# DSF   IDA countries in Sub-Saharan Africa classified as fragile situations
# DSS   Sub-Saharan Africa (IDA-eligible countries)
# DZA   Algeria
# EAP   East Asia & Pacific (excluding high income)
# EAR   Early-demographic dividend
# EAS   East Asia & Pacific
# ECA   Europe & Central Asia (excluding high income)
# ECS   Europe & Central Asia
# ECU   Ecuador
# EGY   Egypt, Arab Rep.
# EMU   Euro area
# ERI   Eritrea
# ESP   Spain
# EST   Estonia
# ETH   Ethiopia
# EUU   European Union
# FCS   Fragile and conflict affected situations
# FIN   Finland
# FJI   Fiji
# FRA   France
# FRO   Faroe Islands
# FSM   Micronesia, Fed. Sts.
# FXS   IDA countries classified as fragile situations, excluding Sub-Saharan Africa
# GAB   Gabon
# GBR   United Kingdom
# GEO   Georgia
# GHA   Ghana
# GIB   Gibraltar
# GIN   Guinea
# GMB   Gambia, The
# GNB   Guinea-Bissau
# GNQ   Equatorial Guinea
# GRC   Greece
# GRD   Grenada
# GRL   Greenland
# GTM   Guatemala
# GUM   Guam
# GUY   Guyana
# HIC   High income
# HKG   Hong Kong SAR, China
# HND   Honduras
# HPC   Heavily indebted poor countries (HIPC)
# HRV   Croatia
# HTI   Haiti
# HUN   Hungary
# IBB   IBRD, including blend
# IBD   IBRD only
# IBT   IDA & IBRD total
# IDA   IDA total
# IDB   IDA blend
# IDN   Indonesia
# IDX   IDA only
# IMN   Isle of Man
# IND   India
# INX   Not classified
# IRL   Ireland
# IRN   Iran, Islamic Rep.
# IRQ   Iraq
# ISL   Iceland
# ISR   Israel
# ITA   Italy
# JAM   Jamaica
# JOR   Jordan
# JPN   Japan
# KAZ   Kazakhstan
# KEN   Kenya
# KGZ   Kyrgyz Republic
# KHM   Cambodia
# KIR   Kiribati
# KNA   St. Kitts and Nevis
# KOR   Korea, Rep.
# KWT   Kuwait
# LAC   Latin America & Caribbean (excluding high income)
# LAO   Lao PDR
# LBN   Lebanon
# LBR   Liberia
# LBY   Libya
# LCA   St. Lucia
# LCN   Latin America & Caribbean
# LDC   Least developed countries: UN classification
# LIC   Low income
# LIE   Liechtenstein
# LKA   Sri Lanka
# LMC   Lower middle income
# LMY   Low & middle income
# LSO   Lesotho
# LTE   Late-demographic dividend
# LTU   Lithuania
# LUX   Luxembourg
# LVA   Latvia
# MAC   Macao SAR, China
# MAF   St. Martin (French part)
# MAR   Morocco
# MCO   Monaco
# MDA   Moldova
# MDE   Middle East (developing only)
# MDG   Madagascar
# MDV   Maldives
# MEA   Middle East & North Africa
# MEX   Mexico
# MHL   Marshall Islands
# MIC   Middle income
# MKD   North Macedonia
# MLI   Mali
# MLT   Malta
# MMR   Myanmar
# MNA   Middle East & North Africa (excluding high income)
# MNE   Montenegro
# MNG   Mongolia
# MNP   Northern Mariana Islands
# MOZ   Mozambique
# MRT   Mauritania
# MUS   Mauritius
# MWI   Malawi
# MYS   Malaysia
# NAC   North America
# NAF   North Africa
# NAM   Namibia
# NCL   New Caledonia
# NER   Niger
# NGA   Nigeria
# NIC   Nicaragua
# NLD   Netherlands
# NOR   Norway
# NPL   Nepal
# NRS   Non-resource rich Sub-Saharan Africa countries
# NRU   Nauru
# NXS   IDA countries not classified as fragile situations, excluding Sub-Saharan Africa
# NZL   New Zealand
# OED   OECD members
# OMN   Oman
# OSS   Other small states
# PAK   Pakistan
# PAN   Panama
# PER   Peru
# PHL   Philippines
# PLW   Palau
# PNG   Papua New Guinea
# POL   Poland
# PRE   Pre-demographic dividend
# PRI   Puerto Rico
# PRK   Korea, Dem. People's Rep.
# PRT   Portugal
# PRY   Paraguay
# PSE   West Bank and Gaza
# PSS   Pacific island small states
# PST   Post-demographic dividend
# PYF   French Polynesia
# QAT   Qatar
# ROU   Romania
# RRS   Resource rich Sub-Saharan Africa countries
# RUS   Russian Federation
# RWA   Rwanda
# SAS   South Asia
# SAU   Saudi Arabia
# SDN   Sudan
# SEN   Senegal
# SGP   Singapore
# SLB   Solomon Islands
# SLE   Sierra Leone
# SLV   El Salvador
# SMR   San Marino
# SOM   Somalia
# SRB   Serbia
# SSA   Sub-Saharan Africa (excluding high income)
# SSD   South Sudan
# SSF   Sub-Saharan Africa
# SST   Small states
# STP   Sao Tome and Principe
# SUR   Suriname
# SVK   Slovak Republic
# SVN   Slovenia
# SWE   Sweden
# SWZ   Eswatini
# SXM   Sint Maarten (Dutch part)
# SXZ   Sub-Saharan Africa excluding South Africa
# SYC   Seychelles
# SYR   Syrian Arab Republic
# TCA   Turks and Caicos Islands
# TCD   Chad
# TEA   East Asia & Pacific (IDA & IBRD countries)
# TEC   Europe & Central Asia (IDA & IBRD countries)
# TGO   Togo
# THA   Thailand
# TJK   Tajikistan
# TKM   Turkmenistan
# TLA   Latin America & the Caribbean (IDA & IBRD countries)
# TLS   Timor-Leste
# TMN   Middle East & North Africa (IDA & IBRD countries)
# TON   Tonga
# TSA   South Asia (IDA & IBRD)
# TSS   Sub-Saharan Africa (IDA & IBRD countries)
# TTO   Trinidad and Tobago
# TUN   Tunisia
# TUR   Turkiye
# TUV   Tuvalu
# TWN   Taiwan, China
# TZA   Tanzania
# UGA   Uganda
# UKR   Ukraine
# UMC   Upper middle income
# URY   Uruguay
# USA   United States
# UZB   Uzbekistan
# VCT   St. Vincent and the Grenadines
# VEN   Venezuela, RB
# VGB   British Virgin Islands
# VIR   Virgin Islands (U.S.)
# VNM   Vietnam
# VUT   Vanuatu
# WLD   World
# WSM   Samoa
# XKX   Kosovo
# XZN   Sub-Saharan Africa excluding South Africa and Nigeria
# YEM   Yemen, Rep.
# ZAF   South Africa
# ZMB   Zambia
# ZWE   Zimbabwe

# %%
wb.get_source()
# Out:
#   id  name
# ----  --------------------------------------------------------------------
#    1  Doing Business
#    2  World Development Indicators
#    3  Worldwide Governance Indicators
#    5  Subnational Malnutrition Database
#    6  International Debt Statistics
#   11  Africa Development Indicators
#   12  Education Statistics
#   13  Enterprise Surveys
#   14  Gender Statistics
#   15  Global Economic Monitor
#   16  Health Nutrition and Population Statistics
#   18  IDA Results Measurement System
#   19  Millennium Development Goals
#   20  Quarterly Public Sector Debt
#   22  Quarterly External Debt Statistics SDDS
#   23  Quarterly External Debt Statistics GDDS
#   25  Jobs
#   27  Global Economic Prospects
#   28  Global Financial Inclusion
#   29  The Atlas of Social Protection: Indicators of Resilience and Equity
#   30  Exporter Dynamics Database – Indicators at Country-Year Level
#   31  Country Policy and Institutional Assessment
#   32  Global Financial Development
#   33  G20 Financial Inclusion Indicators
#   34  Global Partnership for Education
#   35  Sustainable Energy for All
#   36  Statistical Capacity Indicators
#   37  LAC Equity Lab
#   38  Subnational Poverty
#   39  Health Nutrition and Population Statistics by Wealth Quintile
#   40  Population estimates and projections
#   41  Country Partnership Strategy for India (FY2013 - 17)
#   43  Adjusted Net Savings
#   45  Indonesia Database for Policy and Economic Research
#   46  Sustainable Development Goals
#   50  Subnational Population
#   54  Joint External Debt Hub
#   57  WDI Database Archives
#   58  Universal Health Coverage
#   59  Wealth Accounts
#   60  Economic Fitness
#   61  PPPs Regulatory Quality
#   62  International Comparison Program (ICP) 2011
#   63  Human Capital Index
#   64  Worldwide Bureaucracy Indicators
#   65  Health Equity and Financial Protection Indicators
#   66  Logistics Performance Index
#   67  PEFA 2011
#   68  PEFA 2016
#   69  Global Financial Inclusion and Consumer Protection Survey
#   70  Economic Fitness 2
#   71  International Comparison Program (ICP) 2005
#   73  Global Financial Inclusion and Consumer Protection Survey (Internal)
#   75  Environment, Social and Governance (ESG) Data
#   76  Remittance Prices Worldwide (Sending Countries)
#   77  Remittance Prices Worldwide (Receiving Countries)
#   78  ICP 2017
#   79  PEFA_GRPFM
#   80  Gender Disaggregated Labor Database (GDLD)
#   81  International Debt Statistics: DSSI
#   82  Global Public Procurement
#   83  Statistical Performance Indicators (SPI)
#   84  Education Policy
#   85  PEFA_2021_SNG
#   86  Global Jobs Indicators Database (JOIN)
#   87  Country Climate and Development Report (CCDR)
#   88  Food Prices for Nutrition

# %%
wb.search_indicators('energy consumption')
# Out:
# id                             name
# -----------------------------  ------------------------------------------------------------------
# 1.1_TOTAL.FINAL.ENERGY.CONSUM  Total final energy consumption (TFEC)
# 2.1_SHARE.TOTAL.RE.IN.TFEC     Renewable energy consumption(% in TFEC)
# 3.1_RE.CONSUMPTION             Renewable energy consumption (TJ)
# EG.FEC.RNEW.ZS                 Renewable energy consumption (% of total final energy consumption)
# EG.USE.COMM.FO.ZS              Fossil fuel energy consumption (% of total)
# IS.ROD.ENGY.KT                 Road sector energy consumption (kt of oil equivalent)
# IS.ROD.ENGY.PC                 Road sector energy consumption per capita (kg of oil equivalent)
# IS.ROD.ENGY.ZS                 Road sector energy consumption (% of total energy consumption)
